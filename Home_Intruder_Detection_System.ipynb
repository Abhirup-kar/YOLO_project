# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhirup-kar/YOLO_project/blob/main/Home_Intruder_Detection_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 833.4/833.4 kB 61.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 MB 26.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolo11s.pt')

# %% [markdown]
# Datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Q9HE11A5P1khpvtqcu1P")
project = rf.workspace("abhirup-kar").project("home-intrusion-detection-ptd6q")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 30.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 88.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 128.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Home-Intrusion-Detection-2 in yolov11:: 100%|██████████| 91/91 [00:00<00:00, 10295.41it/s]

# %% [markdown]
# Train the Model

# %%
from ultralytics import YOLO
model = YOLO('yolo11s.pt')
res = model.train(data="/content/Home-Intrusion-Detection-2/data.yaml",epochs=20,imgsz=640)
# Out:
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.9.0+cpu CPU (AMD EPYC 7B13)
# ...

# %%
result = model.val()
# Out:
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.9.0+cpu CPU (AMD EPYC 7B13)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1734.7±1427.3 MB/s, size: 37.2 KB)
# val: Scanning /content/Home-Intrusion-Detection-2/valid/labels.cache... 9 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 9/9 4.2Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 5, len(boxes) = 7. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.8s/it 1.8s
#                    all          9          7          1      0.709      0.874      0.721
# Speed: 0.3ms preprocess, 96.1ms inference, 0.0ms loss, 103.3ms postprocess per image
# ...

# %%
model.predict("/content/Home-Intrusion-Detection-2/train/images/OIP-12-_webp.rf.839a4cb8a5902e6e72004e9d473e5d4c.jpg")
# Out:
# image 1/1 /content/Home-Intrusion-Detection-2/train/images/OIP-12-_webp.rf.839a4cb8a5902e6e72004e9d473e5d4c.jpg: 416x640 1 intruder detected, 159.4ms
# Speed: 1.3ms preprocess, 159.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'intruder detected'}
#  obb: None
#  orig_img: array([[[121,  68,  71],
#          [125,  70,  73],
#          [128,  71,  74],
#          ...,
#          [ 98, 122, 110],
#          [100, 124, 112],
#          [103, 127, 115]],
#
#         [[121,  68,  71],
#          [124,  69,  72],
#          [128,  71,  74],
#          ...,
#          [ 95, 120, 110],
#          [ 95, 120, 110],
#          [ 97, 122, 112]],
#
#         [[121,  68,  71],
#          [124,  69,  72],
#          [128,  71,  74],
#          ...,
#          [ 91, 117, 111],
#          [ 90, 116, 110],
# ...

# %%
# !yolo task=detect mode=predict model =/content/runs/detect/train/weights/best.pt source=/content/Home-Intrusion-Detection-2/valid/images/OIP-15-_webp.rf.61b20832e060dddacd1fdf88f15fea74.jpg save=True
# Out:
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.9.0+cpu CPU (AMD EPYC 7B13)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /content/Home-Intrusion-Detection-2/valid/images/OIP-15-_webp.rf.61b20832e060dddacd1fdf88f15fea74.jpg: 480x640 2 intruder detecteds, 182.6ms
# Speed: 2.1ms preprocess, 182.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model =/content/runs/detect/train/weights/best.pt conf = 0.2 source=/content/Home-Intrusion-Detection-2/test/images/OIP-6-_webp.rf.6cdcc1d95dda6a95c15bc64e990637ec.jpg save=True
# Out:
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.9.0+cpu CPU (AMD EPYC 7B13)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /content/Home-Intrusion-Detection-2/test/images/OIP-6-_webp.rf.6cdcc1d95dda6a95c15bc64e990637ec.jpg: 416x640 (no detections), 120.6ms
# Speed: 2.0ms preprocess, 120.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /content/runs/detect/predict-2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model =/content/runs/detect/train/weights/best.pt conf = 0.2 source=/content/Home-Intrusion-Detection-2/test/images/OIP-18-_webp.rf.28e7d11661744a7739dabe6291e7d47f.jpg save=True
# Out:
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.9.0+cpu CPU (AMD EPYC 7B13)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /content/Home-Intrusion-Detection-2/test/images/OIP-18-_webp.rf.28e7d11661744a7739dabe6291e7d47f.jpg: 384x640 1 intruder detected, 119.9ms
# Speed: 1.8ms preprocess, 119.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict-3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model =/content/runs/detect/train/weights/best.pt conf = 0.2 source=/content/Home-Intrusion-Detection-2/valid/images/OIP-16-_webp.rf.a8094ae21f0e946bebffe0034eb5bb60.jpg save=True
# Out:
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.9.0+cpu CPU (AMD EPYC 7B13)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /content/Home-Intrusion-Detection-2/valid/images/OIP-16-_webp.rf.a8094ae21f0e946bebffe0034eb5bb60.jpg: 352x640 1 intruder detected, 120.3ms
# Speed: 1.8ms preprocess, 120.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to /content/runs/detect/predict-4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import os

base_path = "/content/Home-Intrusion-Detection-2/"
folders_to_predict = ["train/images", "valid/images", "test/images"]
model_path = "/content/runs/detect/train/weights/best.pt"
conf_threshold = 0.2

for folder in folders_to_predict:
    image_folder_path = os.path.join(base_path, folder)
    print(f"\nPredicting images in {image_folder_path}...")
    # Use the !yolo command with the folder path as source to predict all images in it
    # !yolo task=detect mode=predict model="{model_path}" conf={conf_threshold} source="{image_folder_path}" save=True
# Out:
# Predicting images in /content/Home-Intrusion-Detection-2/train/images...
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.9.0+cpu CPU (AMD EPYC 7B13)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/30 /content/Home-Intrusion-Detection-2/train/images/OIP-1-_webp.rf.ac8c0afbf224ea331a76fe3e8d6ccdbd.jpg: 416x640 1 intruder detected, 120.9ms
# image 2/30 /content/Home-Intrusion-Detection-2/train/images/OIP-10-_webp.rf.c4b1f5c8646cd172e984203e6d50efeb.jpg: 576x640 1 intruder detected, 131.9ms
# image 3/30 /content/Home-Intrusion-Detection-2/train/images/OIP-11-_webp.rf.2a42b98a4d502ca8baa1293c9485df5c.jpg: 480x640 1 intruder detected, 174.7ms
# image 4/30 /content/Home-Intrusion-Detection-2/train/images/OIP-12-_webp.rf.839a4cb8a5902e6e72004e9d473e5d4c.jpg: 416x640 2 intruder detecteds, 103.8ms
# ...
